# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.datasets import load_iris
# For Visualization
import seaborn as sb
import matplotlib.pyplot as plt

# %%
clf = DecisionTreeClassifier()

# %%
d = load_iris()
X, y = d.data, d.target

# %%
# Splitting the data for training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
clf.fit(X_train, y_train)
hypothesis = clf_fit.predict(X_test)
hypothesis
# Out:
# array([2, 0, 1, 1, 2, 2, 1, 2, 2, 2, 2, 2, 2, 0, 0, 0, 1, 2, 0, 0, 1, 1,
#        0, 2, 2, 1, 1, 2, 1, 0])

# %%
plot_tree(clf_fit, filled=True)
# Out:
# [Text(0.375, 0.875, 'x[2] <= 2.45\ngini = 0.665\nsamples = 112\nvalue = [34, 38, 40]'),
#  Text(0.25, 0.625, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]'),
#  Text(0.5, 0.625, 'x[2] <= 4.75\ngini = 0.5\nsamples = 78\nvalue = [0, 38, 40]'),
#  Text(0.25, 0.375, 'x[3] <= 1.65\ngini = 0.054\nsamples = 36\nvalue = [0, 35, 1]'),
#  Text(0.125, 0.125, 'gini = 0.0\nsamples = 35\nvalue = [0, 35, 0]'),
#  Text(0.375, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.75, 0.375, 'x[3] <= 1.7\ngini = 0.133\nsamples = 42\nvalue = [0, 3, 39]'),
#  Text(0.625, 0.125, 'gini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.875, 0.125, 'gini = 0.054\nsamples = 36\nvalue = [0, 1, 35]')]

# %%
print("Accuracy: ", accuracy_score(y_test, hypothesis) * 100, "%")
# Out:
# Accuracy:  96.66666666666667 %

# %%
cm = confusion_matrix(y_test, hypothesis)
fig, ax,

# %%
sb.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('True')
# Out:
# Text(50.722222222222214, 0.5, 'True')

# %%
# Regression with DT
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.datasets import load_diabetes

# %%
dtr = DecisionTreeRegressor()

# %%
ds = load_diabetes()
X, y = ds.data, ds.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
hypothesis = dtr.predict(X_test)

# %%
fig, ax = plt.subplots(figsize=(4,4))
plt.plot(hypothesis)
plt.plot(y_test, color='red')
plt.show()

# %%
print(X_train.shape, y_train.shape)
# Out:
# (331, 10) (331,)
